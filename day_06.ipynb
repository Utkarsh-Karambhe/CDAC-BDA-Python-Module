# %% [markdown]
# ### Assignment 1: Smart Home Appliance Control

# %%
class SmartThermostat:
    MIN_TEMP = 10.0
    MAX_TEMP = 35.0

    def __init__(self, appliance_name, initial_temp):
        self.__appliance_name = appliance_name

        if(self.MIN_TEMP <= initial_temp <= self.MAX_TEMP):
            self.__target_temp = initial_temp
        else:
            self.__target_temp = 22.0

    @property
    def target_temp(self):
        return self.__target_temp

    @target_temp.setter
    def target_temp(self, new_temp):
        if(self.MIN_TEMP<=new_temp<=self.MAX_TEMP):
            self.__target_temp = new_temp
        else:
            raise ValueError("Temperature must be between 10.0 and 35.0")

    @property
    def appliance_name(self):
        return self.__appliance_name


thermostat1 = SmartThermostat("Living Room", 25.0)
thermostat2 = SmartThermostat("Kitchen", 36.0)

print(thermostat2.target_temp)
print(thermostat1.target_temp)
# Out:
# 22.0
# 25.0
